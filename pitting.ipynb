# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/My Drive/'
# Out:
# jason

# %%
DATA_DIR = '/content/gdrive/My_Drive/jason/pitting/data/'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 7.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8-seg.pt")  # build a new model from scratch

# Use the model

model.train(data='/content/gdrive/My Drive/jason/pitting/config.yaml', epochs=1000, imgsz=640, project = '/content/gdrive/My Drive/jason/pitting/runs', patience = 400)
# Out:
# ...
# 100%|██████████| 88.1M/88.1M [00:00<00:00, 300MB/s]
# Ultralytics YOLOv8.2.0 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import os

from ultralytics import YOLO

# Load a model
model = YOLO("/content/gdrive/MyDrive/jason/pitting/runs/S/weights/small.pt")  # build a new model from scratch

# Use the model
#results = model(['IMG_2705.jpg'])
#results.show()

#model.predict('test3.jpg', save=True, show=True, imgsz=320, conf=0.5)
model.val(plots=True,  project = '/content/gdrive/My Drive/jason/pitting/runs')
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8s-seg summary (fused): 195 layers, 11779987 parameters, 0 gradients, 42.4 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 4.78MB/s]
# val: Scanning /content/gdrive/My Drive/jason/pitting/data/labels/validation.cache... 10 images, 0 backgrounds, 0 corrupt: 100%|██████████| 10/10 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:22<00:00, 22.21s/it]
#                    all         10         24       0.79        0.5      0.583      0.311       0.79        0.5      0.563      0.278
# Speed: 9.2ms preprocess, 1085.1ms inference, 0.0ms loss, 339.4ms postprocess per image
# Results saved to /content/gdrive/My Drive/jason/pitting/runs/val4
# ultralytics.utils.metrics.SegmentMetrics object with attributes:
#
# ap_class_index: array([0])
# ...
